# %%
from fastapi import FastAPI,HTTPException
from pydantic import BaseModel
from motor.motor_asyncio import AsyncIOMotorClient
from bson import ObjectId
import os
from dotenv import load_dotenv
from pydantic import BaseModel
from typing import List
import pandas as pd 
load_dotenv()
# Out:
# False

# %%
MONGO_URI = "mongodb+srv://prabhat1897:prabhat1234@cluster-app.08kkqg6.mongodb.net/?appName=Cluster-app"
#MONGO_URI= os.getenv("MONGO_URI")
client = AsyncIOMotorClient(MONGO_URI)
my_db = client['expense_manager']
my_coll = my_db['expenses']

# %%
my_coll.insert_one({"date":"2025-12-05", "amount":100, "category":"Food","notes":"Ate dosa at amoga"})
# Out:
# <Future pending cb=[_chain_future.<locals>._call_check_cancel() at C:\Users\DELL\anaconda3\Lib\asyncio\futures.py:391]>
